# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
###### NETOYAGE ET PRÉPARATION DES DONNÉES ######
df = pd.read_csv('data.csv') #chargement des données
df['tax'] = df['tax'].fillna(df['tax'].mode()[0])
df['gender'] = df['gender'].fillna('Inconnu')
df['country'] = df['country'].fillna('Inconnu')
df['price_paid'] = (
    df['price_paid']
    .astype(str)
    .str.replace('$','', regex = False)
    .str.replace(',','', regex = False)
    .astype(float)
)
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#       gender       ip_address        country  price_paid   tax
# 0       Male    160.119.8.119         Canada        5.36  20.0
# 1     Female   210.51.172.132         Canada        8.32  20.0
# 2       Male    213.8.101.145  United States        3.73  20.0
# 3     Female    5.140.237.101  United States        3.70  20.0
# 4       Male  106.252.162.233        Morocco        9.24  20.0
# ..       ...              ...            ...         ...   ...
# 995   Female   193.84.247.144         France        3.63  20.0
# 996   Female   188.219.12.109        Inconnu        4.59  20.0
# 997     Male     199.80.60.87  United States        7.54  20.0
# 998     Male      0.183.63.11  United States        5.81  20.0
# 999  Inconnu   170.193.249.83         Canada        8.01  20.0
#
# [1000 rows x 10 columns]

# %%
gender = (
    df
    .groupby('gender')['price_paid']
    .sum()
)
gender
# Out:
# gender
# Female     3165.26
# Inconnu     463.06
# Male       2833.61
# Name: price_paid, dtype: float64

# %%
plt.figure(figsize = (10,5))
gender.plot(kind = 'pie', autopct = '%1.1f%%')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
usa = df[df['country'] == 'United States' ]
usa
usa['date'] = pd.to_datetime(df['date'], format = '%m/%d/%Y')
# Out:
# C:\Users\TIMaystar\AppData\Local\Temp\ipykernel_11776\1159025045.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa['date'] = pd.to_datetime(df['date'], format = '%m/%d/%Y')

# %%
usa_j = (
    usa
    .groupby('date')
    .size()
    .sort_index(ascending = True)
)

# %%
usa_pv = usa_j[usa_j > 15]

# %%
usa_pv
# Out:
# date
# 2021-03-07    16
# 2021-03-16    17
# 2021-03-17    17
# 2021-03-20    19
# 2021-03-27    18
# dtype: int64

# %%
usa_mars = usa[usa['date'].isin(['2021-03-07','2021-03-16','2021-03-17','2021-03-27','2021-03-20'])]
# Out:
# C:\Users\TIMaystar\AppData\Local\Temp\ipykernel_11776\3884592307.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   usa_mars = usa[usa['date'].isin(['2021-03-07','2021-03-16','2021-03-17','2021-03-27','2021-03-20'])]

# %%
_2021_03_20 = usa_mars[usa_mars['date'].isin(['2021-03-20'])]
# Out:
# C:\Users\TIMaystar\AppData\Local\Temp\ipykernel_11776\422246074.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   _2021_03_20 = usa_mars[usa_mars['date'].isin(['2021-03-20'])]

# %%
_2021_03_20
# Out:
#       id       date first_name      last_name                         email  \
# 17    18 2021-03-20       Esta        Boulden       ebouldenh@posterous.com
# 33    34 2021-03-20        Cam  Francescoccio        cfrancescocciox@si.edu
# 37    38 2021-03-20      Byram         Dudman  bdudman11@barnesandnoble.com
# 44    45 2021-03-20  Maribelle          Shiel         mshiel18@gravatar.com
# 62    63 2021-03-20     Marlee           Dyas         mdyas1q@instagram.com
# 96    97 2021-03-20    Devonne       Clowsley        dclowsley2o@ebay.co.uk
# 197  198 2021-03-20     Briano        Stapels        bstapels5h@archive.org
# 266  267 2021-03-20    Malinde         Croose          mcroose7e@flickr.com
# 315  316 2021-03-20        Saw     Brookesbie    sbrookesbie8r@edublogs.org
# 396  397 2021-03-20   Marshall           Kuhn                mkuhnb0@ft.com
# 461  462 2021-03-20     Mahala          Oxlee          moxleect@tinypic.com
# 501  502 2021-03-20   Gardener        Bentzen           gbentzendx@army.mil
# 522  523 2021-03-20      Wilek       Lernihan        wlernihanei@unesco.org
# 528  529 2021-03-20    Nikolai        Cockram       ncockrameo@addtoany.com
# 637  638 2021-03-20      Madel       Sylvaine        msylvainehp@sbwire.com
# 772  773 2021-03-20     Brynne       Cottrell        bcottrelllg@spiegel.de
# 804  805 2021-03-20     Caesar       Spellesy         cspellesymc@lycos.com
# 808  809 2021-03-20     Barnie       Mulvenna         bmulvennamg@nifty.com
# 981  982 2021-03-20      Marty           Scad           mscadr9@addthis.com
#
#       gender       ip_address        country  price_paid   tax
# 17   Inconnu  220.109.140.190  United States        3.16  20.0
# 33    Female      177.11.5.62  United States        5.34  20.0
# 37      Male     37.111.199.4  United States        9.50  20.0
# 44      Male  193.194.124.171  United States        3.37  20.0
# 62      Male    110.71.126.71  United States        7.68  20.0
# 96    Female   118.214.156.60  United States        4.71  20.0
# 197     Male    0.139.242.150  United States        7.41  20.0
# 266   Female   231.105.40.170  United States        8.65  20.0
# 315     Male      57.2.187.97  United States        3.09  20.0
# 396   Female   218.65.196.247  United States        5.66  20.0
# 461   Female      37.46.21.23  United States        4.84  20.0
# 501   Female   125.204.23.141  United States        8.49  20.0
# 522   Female  233.153.246.179  United States        6.73  20.0
# 528     Male    82.163.12.117  United States        6.20  20.0
# 637     Male   140.192.254.47  United States        4.49  20.0
# 772   Female  154.115.136.104  United States        7.22  20.0
# 804   Female    206.68.68.166  United States        9.51  20.0
# 808   Female    14.113.63.103  United States        8.35  20.0
# 981   Female   118.163.178.56  United States        6.46  20.0

# %%
_03_20_g = (
    _2021_03_20
    .groupby('gender')
    .size()
    .sort_values(ascending = False)
)
_03_20_g
# Out:
# gender
# Female     11
# Male        7
# Inconnu     1
# dtype: int64

# %%
plt.figure(figsize = (10,5))
_03_20_g.plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: >

# %%
usa_03_20_g_pp = (
    _2021_03_20
    .groupby('gender')['price_paid']
    .sum()
    .sort_values(ascending = False)
)
ttpp = usa_03_20_g_pp.sum()

# %%
len(usa_03_20_g_pp)
# Out:
# 3

# %%
print(f"{ttpp}$")
# Out:
# 120.85999999999999$

# %%
plt.figure(figsize = (10,5))
usa_03_20_g_pp.plot(kind = 'pie', autopct = '%1.1f%%')
plt.xlabel(f"Le montant total:{ttpp}$\n"
          f"Femme:{usa_03_20_g_pp[0]}$\n"
          f"Homme:{usa_03_20_g_pp[1]}$\n"
          f"Iconnu:{usa_03_20_g_pp[2]}$")
plt.ylabel('')
plt.show()
# Out:
# C:\Users\TIMaystar\AppData\Local\Temp\ipykernel_11776\38770758.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f"Femme:{usa_03_20_g_pp[0]}$\n"
# C:\Users\TIMaystar\AppData\Local\Temp\ipykernel_11776\38770758.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f"Homme:{usa_03_20_g_pp[1]}$\n"
# C:\Users\TIMaystar\AppData\Local\Temp\ipykernel_11776\38770758.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f"Iconnu:{usa_03_20_g_pp[2]}$")

# %%
df['price_paid'].nlargest(5)
# Out:
# 168    10.00
# 418    10.00
# 54      9.99
# 196     9.99
# 287     9.98
# Name: price_paid, dtype: float64

# %%
mars_2021_03_17 = usa_mars[usa_mars['date'].isin(['2021-03-17'])]
# Out:
# C:\Users\TIMaystar\AppData\Local\Temp\ipykernel_11776\2688697674.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   mars_2021_03_17 = usa_mars[usa_mars['date'].isin(['2021-03-17'])]

# %%
mars_2021_03_17vp = mars_2021_03_17['price_paid'].nlargest(3)

# %%
mars_2021_03_17
# Out:
#       id       date first_name   last_name                          email  \
# 2      3 2021-03-17        Erl  Kilminster          ekilminster2@etsy.com
# 40    41 2021-03-17         Em       Dupoy           edupoy14@foxnews.com
# 53    54 2021-03-17       Ange     Purvess            apurvess1h@ucsd.edu
# 61    62 2021-03-17       Mill     Haughan            mhaughan1p@ox.ac.uk
# 94    95 2021-03-17    Shannan  Giacomozzo          sgiacomozzo2m@psu.edu
# 120  121 2021-03-17      Tasha   Monkhouse  tmonkhouse3c@chronoengine.com
# 138  139 2021-03-17       Greg    Bernucci    gbernucci3u@themeforest.net
# 144  145 2021-03-17      Beale    Jannaway            bjannaway40@nba.com
# 230  231 2021-03-17  Fairleigh       Gouny             fgouny6e@jimdo.com
# 434  435 2021-03-17      Clara  Dawidowicz       cdawidowiczc2@smh.com.au
# 636  637 2021-03-17      Avery      Piecha              apiechaho@bbb.org
# 675  676 2021-03-17     Corine   Sictornes     csictornesir@google.com.hk
# 697  698 2021-03-17     Roxane        Erbe              rerbejd@google.de
# 865  866 2021-03-17   Simmonds   Hindsberg        shindsbergo1@smh.com.au
# 884  885 2021-03-17     Jeromy     Clemits   jclemitsok@printfriendly.com
# 984  985 2021-03-17    Koressa      Abbado    kabbadorc@printfriendly.com
# 998  999 2021-03-17    Paquito       Tesoe         ptesoerq@rakuten.co.jp
#
#       gender       ip_address        country  price_paid   tax
# 2       Male    213.8.101.145  United States        3.73  20.0
# 40      Male    59.105.241.85  United States        3.45  20.0
# 53      Male   190.14.100.103  United States        6.57  20.0
# 61    Female    75.242.73.109  United States        6.17  20.0
# 94    Female   101.143.192.29  United States        5.80  20.0
# 120     Male   201.119.190.49  United States        8.97  20.0
# 138     Male   58.166.190.147  United States        3.03  20.0
# 144   Female    201.218.125.4  United States        5.87  20.0
# 230   Female       52.75.9.48  United States        6.93  20.0
# 434     Male  179.186.255.233  United States        7.66  20.0
# 636     Male    89.83.108.152  United States        4.50  20.0
# 675   Female   111.204.252.75  United States        8.68  20.0
# 697     Male    155.54.81.236  United States        3.95  20.0
# 865   Female    29.157.147.40  United States        6.67  20.0
# 884   Female  116.211.235.163  United States        6.15  20.0
# 984  Inconnu   20.188.127.195  United States        4.33  20.0
# 998     Male      0.183.63.11  United States        5.81  20.0

# %%
mars_2021_03_17[mars_2021_03_17['price_paid'].isin(mars_2021_03_17vp)] # ici on veut rechercher tous les valeurs, on a pas besoin d'utiliser un *
# Out:
#       id       date first_name   last_name                          email  \
# 120  121 2021-03-17      Tasha   Monkhouse  tmonkhouse3c@chronoengine.com
# 434  435 2021-03-17      Clara  Dawidowicz       cdawidowiczc2@smh.com.au
# 675  676 2021-03-17     Corine   Sictornes     csictornesir@google.com.hk
#
#      gender       ip_address        country  price_paid   tax
# 120    Male   201.119.190.49  United States        8.97  20.0
# 434    Male  179.186.255.233  United States        7.66  20.0
# 675  Female   111.204.252.75  United States        8.68  20.0

# %%
mars_2021_03_17vp.iloc[0] # l'index de cette Series un peu bizzare, mais c'est normal, si  on veut l'index classique on peut utiliser .iloc
# Out:
# np.float64(8.97)

# %%
mars_2021_03_17vp
# Out:
# 120    8.97
# 675    8.68
# 434    7.66
# Name: price_paid, dtype: float64

# %%
mars_2021_03_17[mars_2021_03_17['price_paid'] == 8.97]
# Out:
#       id       date first_name  last_name                          email  \
# 120  121 2021-03-17      Tasha  Monkhouse  tmonkhouse3c@chronoengine.com
#
#     gender      ip_address        country  price_paid   tax
# 120   Male  201.119.190.49  United States        8.97  20.0

# %%
df[df['ip_address'] == '160.119.8.119']
# Out:
#    id        date first_name last_name                 email gender  \
# 0   1  03/28/2021    Marylin    Alders  malders0@shop-pro.jp   Male
#
#       ip_address country  price_paid   tax
# 0  160.119.8.119  Canada        5.36  20.0

# %%
df['price_paid'][1]
# Out:
# np.float64(8.32)

# %%
df['tax'][1]
# Out:
# np.float64(20.0)

# %%
df['price_paid'][1] - (df['tax'][1] * (df['tax'][1] / 100 ))
# Out:
# np.float64(4.32)

# %%
df['tax'] * (df['tax'][1] / 100)
# Out:
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0
#       ...
# 995    4.0
# 996    4.0
# 997    4.0
# 998    4.0
# 999    4.0
# Name: tax, Length: 1000, dtype: float64

# %%
df['price_paid'][1] - (df['price_paid'][1] * df['tax'][1] / 100) #La bonne formule (taxe sur le prix)
# Out:
# np.float64(6.656000000000001)
